# %%
from PIL import ImageFont, ImageDraw, Image 
import matplotlib.pyplot as plt

# %%
img = Image.open(r"C:\Users\sweth\Downloads\Kgf-2-Meme-Templates-5.jpg")
draw = ImageDraw.Draw(img)

# %%
img = Image.open(r"C:\Users\sweth\Downloads\Kgf-2-Meme-Templates-5.jpg")
draw = ImageDraw.Draw(img)

text1 = "***malli exam lo fail ayyava"
text2 = """Me*: Gayapadina Simham nundi 
vachina swasa ...
Garjana kante 
Bayamkaranga untundi...."""
text3 = "Rey.. last 4 years nundi ade cheptunav"

font1 = ImageFont.truetype('arial.ttf', 20)
font2 = ImageFont.truetype('arial.ttf', 20)
font3 = ImageFont.truetype('arial.ttf', 20)

draw.text((10,10), font = font1, text= text1, fill=(255,255,255), align='center')
draw.text((10,210), font = font2, text= text2, fill=(255,255,255), align='center')
draw.text((280,440), font = font3, text= text3, fill=(255,255,255), align='center')

plt.figure(figsize=(12,8))
plt.imshow(img)
plt.savefig(r"C:\Users\sweth\Downloads\Kgf-2-Memes.jpg")

# %%
img = Image.open(r"C:\Users\sweth\Downloads\image.jpg")
print("Height of img", img.height)
print("Width of img", img.width)

img_width = img.width
img_height = 100 + img.height

new_img = Image.new(mode="RGB", size= (img_width,img_height), color=(0,0,0))
new_img.paste(img,(0, new_img.height - img.height) )

plt.figure(figsize=(10,10))
plt.imshow(new_img)
# Out:
# Height of img 1597
# Width of img 800

# %%
draw = ImageDraw.Draw(new_img)


text1 = """After completion of Machine learning.."""
text2 = "We* : Forgot python basics"
text3 = """Abhishek...."""


font1 = ImageFont.truetype('arial.ttf', 40)
font2 = ImageFont.truetype('arial.ttf', 40)
font3 = ImageFont.truetype('arial.ttf', 60)

draw.text((50,10), font = font1, text= text1, fill=(255,255,255), align='center')
draw.text((50,100), font = font2, text= text2, fill=(0,0,255), align='center')
draw.text((10,680), font = font3, text= text3, fill=(255,0,0), align='center')

plt.figure(figsize=(10,10))
plt.imshow(new_img)
plt.savefig(r"C:\Users\sweth\Downloads\Kgf-2-Memes2.jpg")

# %%
import numpy as np

# %%
img1 = Image.open(r"C:\Users\sweth\Downloads\images_1.jpg")
img2 = Image.open(r"C:\Users\sweth\Downloads\image_2.jpg")

print(img1.width,img1.height)
print(img2.width,img2.height)
# Out:
# 275 183
# 288 180

# %%
img1 = img1.resize((200,183))
img2 = img2.resize((200,183))

img1_array = np.asarray(img1)
img2_array = np.asarray(img2)

new_img = np.concatenate((img1_array, img2_array), axis=0)
new_img
# Out:
# array([[[229, 185, 112],
#         [229, 185, 112],
#         [230, 186, 113],
#         ...,
#         [110, 147,  53],
#         [ 86, 125,  95],
#         [ 46,  84,  61]],
#
#        [[229, 185, 112],
#         [230, 186, 113],
#         [230, 186, 113],
#         ...,
#         [128, 149,  66],
#         [105, 125,  90],
#         [ 82, 101,  75]],
#
#        [[229, 185, 112],
#         [230, 186, 113],
#         [230, 186, 113],
#         ...,
#         [140, 144,  75],
#         [124, 122,  81],
#         [101,  98,  66]],
#
#        ...,
#
#        [[150,  39,  68],
#         [144,  43,  69],
#         [164,  30,  67],
#         ...,
#         [  4,  12,   4],
#         [  0,  14,   0],
#         [ 14,  31,  12]],
#
#        [[178,  41,  79],
#         [169,  42,  76],
#         [190,  34,  79],
#         ...,
#         [  5,  14,   5],
#         [  3,  17,   0],
#         [ 17,  33,  14]],
#
#        [[200,  29,  79],
#         [183,  25,  70],
#         [202,  17,  71],
# ...

# %%
new_array_img = Image.fromarray(new_img)
plt.imshow(new_array_img)
